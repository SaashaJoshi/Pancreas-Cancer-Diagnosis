# %% [markdown]
# <a href="https://colab.research.google.com/github/SaashaJoshi/Pancreas-Cancer/blob/master/Rotate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import cv2
import random
import numpy as np
import tensorflow as tf
from tqdm import tqdm
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from glob import glob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data_path = 'drive/My Drive/Pancreas-CT-PNG/PANCREAS_0001'
output_path = working_path = 'drive/My Drive/'
g = glob(data_path + '/*.png')

# Print out the first 5 file names to verify we're in the right folder.
print ("Total of %d images.\nFirst 5 filenames:" % len(g))
print ('\n'.join(g[:5]))
# Out:
# Total of 0 images.
# First 5 filenames:

# %%
from PIL import Image
import os
import tensorflow as tf
import numpy as np
from matplotlib.pyplot import imshow

patient_dirs = 'drive/My Drive/Pancreas-CT-PNG/PANCREAS_0001'

new_path = 'drive/My Drive/PANCREAS/train_images'
if not os.path.exists(new_path):
    os.makedirs(new_path)

# %%
patient_dirs = 'drive/My Drive/Pancreas-CT-PNG/PANCREAS_0001'
for count, filename in enumerate(os.listdir(patient_dirs)): 
  dst ="1" + str(filename)
  print(dst)
  src = patient_dirs + '/' + filename 
  dst = new_path + '/' + dst 
  # os.rename(src, dst)

# %%
new_path = 'drive/My Drive/PANCREAS/train_images'
dirs = os.listdir(new_path)

for f in dirs:
  fullpath = os.path.join(new_path,f) 
  if os.path.isfile(fullpath):    # os.path.isfile returns boolean value whether file exists or not
    img=Image.open(fullpath)    # opens and identifies given image file
    img_rotate = img.rotate(180)     # returns converted copy of image
    imshow(img_rotate)
    img_rotate.save(fullpath)

# %%
from PIL import Image
import os
import tensorflow as tf
import numpy as np
from matplotlib.pyplot import imshow

patient_mask_dirs = 'drive/My Drive/Pancreas-CT-PNG/pancreas-png-mask'

new_mask_path = 'drive/My Drive/PANCREAS/train_masks'
if not os.path.exists(new_mask_path):
    os.makedirs(new_mask_path)

# %%
patient_mask_dirs = 'drive/My Drive/Pancreas-CT-PNG/pancreas-png-mask/1'
for count, filename in enumerate(os.listdir(patient_mask_dirs)): 
  dst ="1000" + str(count) + '.png'
  src = patient_mask_dirs + '/' + filename 
  dst = new_mask_path + '/' + dst 
  # os.rename(src, dst)

# %%
# patient_mask_dirs = 'drive/My Drive/PANCREAS/Untitled'
# for count, filename in enumerate(os.listdir(patient_mask_dirs)): 
#   dst ="1000" + str(count) + '.png'
#   src = patient_mask_dirs + '/' + filename 
#   dst = new_mask_path + '/' + dst 
#   os.rename(src, dst)

# %%
new_test_path = 'drive/My Drive/PANCREAS/test_images'
if not os.path.exists(new_test_path):
    os.makedirs(new_test_path)

# %%
patient_dirs = 'drive/My Drive/Pancreas-CT-PNG/PANCREAS_0011'
for count, filename in enumerate(os.listdir(patient_dirs)): 
  dst ="11" + str(filename)
  src = patient_dirs + '/' + filename 
  dst = new_test_path + '/' + dst 
  # os.rename(src, dst)

# %%
new_test_path = 'drive/My Drive/PANCREAS/test_images'
dirs = os.listdir(new_test_path)

for f in dirs:
  fullpath = os.path.join(new_test_path,f) 
  if os.path.isfile(fullpath):    # os.path.isfile returns boolean value whether file exists or not
    img=Image.open(fullpath)    # opens and identifies given image file
    img_rotate = img.rotate(180)     # returns converted copy of image
    imshow(img_rotate)
    img_rotate.save(fullpath)
